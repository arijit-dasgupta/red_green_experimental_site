# %%
# THIS WORKS

from moviepy.video.io.VideoFileClip import VideoFileClip
from moviepy.video.io.gif_writers import write_gif_with_imageio
def convert_mp4_to_gif(input_file, output_file, fps=None):
    """
    Converts an MP4 video to a GIF.
    
    Parameters:
        input_file (str): Path to the input MP4 file.
        output_file (str): Path to save the output GIF file.
        fps (int, optional): Frames per second for the GIF. Defaults to the original FPS of the video.
    """
    try:
        # Load the video file
        video = VideoFileClip(input_file)

        # Use the provided FPS or the video's original FPS
        gif_fps = fps if fps else video.fps


        # Convert to GIF
        write_gif_with_imageio(video, output_file, fps=int(gif_fps), loop = 0)

        print(f"GIF successfully created: {output_file}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
input_mp4 = "/Users/arijitdasgupta/Desktop/projects/mental_physics_trials/pre_pilot/instruc3/high_res_obs.mp4"  # Replace with your MP4 file
output_gif = "/Users/arijitdasgupta/Desktop/projects/mental_physics_trials/pre_pilot/instruc3/high_res_obs.gif"  # Desired output file
convert_mp4_to_gif(input_mp4, output_gif, fps=None)  # Specify FPS, or pass None to use original FPS
# Out:
# MoviePy - Building file /Users/arijitdasgupta/Desktop/projects/mental_physics_trials/pre_pilot/instruc3/high_res_obs.gif with imageio.
# GIF successfully created: /Users/arijitdasgupta/Desktop/projects/mental_physics_trials/pre_pilot/instruc3/high_res_obs.gif

# %%
scene_datas[-1].get('rg_outcome')

# %%
scene_datas[-1].get('rg_hit_timestep').item()

# %%
{int(k): v for k, v in scene_datas[-1].get("step_data", {}).item().items() if int(k)<=scene_datas[-1].get("rg_hit_timestep").item()}
